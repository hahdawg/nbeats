# %%
import m4

# %%
raw = m4.load_data()

# %%
proc = m4.process_data(raw)

# %%
bg = m4.generate_batches(proc, batch_size=32, bcst_len=64, fcst_len=32)

# %%
x_tr, x_val, y_tr, y_val, _ = next(bg)

# %%
x_tr.shape
# Out:
# (17, 64)

# %%
xs = np.concatenate([x_tr, y_tr], axis=1)

# %%
plt.plot(xs[5, :])
